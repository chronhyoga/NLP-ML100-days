# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = list(set(whole_words))
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for index, word in enumerate(whole_words):
    word_index[word] = index
    index_word[index] = word

# %%
word_index
# Out:
# {'beans': 0,
#  'placed': 1,
#  'puréed': 2,
#  'price': 3,
#  'coming': 4,
#  'or': 5,
#  'obviously': 6,
#  'mayo': 7,
#  'styrofoam': 8,
#  'These': 9,
#  'pack': 10,
#  'over-whelm': 11,
#  'helped': 12,
#  'juice': 13,
#  'difference': 14,
#  'rotating': 15,
#  'still': 16,
#  'seen': 17,
#  'generous': 18,
#  'They': 19,
#  'imaginative': 20,
#  'Those': 21,
#  'delish': 22,
#  'call': 23,
#  'silently': 24,
#  'the': 25,
#  'just': 26,
#  'may': 27,
#  'fries': 28,
#  'restaraunt': 29,
#  'Steve': 30,
#  'devine': 31,
#  'horrible': 32,
#  'hoping': 33,
#  'BBQ': 34,
#  'serves': 35,
#  'asked': 36,
#  'Although': 37,
#  'Sorry': 38,
#  'dinners': 39,
#  'simply': 40,
#  'foot': 41,
#  'Madison': 42,
#  'after': 43,
#  'Heimer': 44,
#  'bite': 45,
#  'value': 46,
#  'if': 47,
#  'saffron': 48,
#  'VERY': 49,
#  'Worst': 50,
#  'place': 51,
#  'try': 52,
#  'inviting': 53,
#  'walked': 54,
#  'beef': 55,
#  'wildly': 56,
#  'array': 57,
#  'fill': 58,
#  'has': 59,
#  'honor': 60,
#  'sashimi': 61,
#  'fell': 62,
#  'meals': 63,
#  'Wow': 64,
#  'non-customer': 65,
#  'one': 66,
#  'Paradise': 67,
#  'Fridays': 68,
#  'Generous': 69,
#  'crumby': 70,
#  'Tucson': 71,
#  'Mango': 72,
#  'eggplant': 73,
#  'visited': 74,
#  'Casino': 75,
#  'Palm': 76,
#  'Food': 77,
#  'ice': 78,
#  'inexpensive': 79,
#  'half': 80,
#  'kitchen': 81,
#  'military': 82,
#  'alone': 83,
#  'during': 84,
#  'taco': 85,
#  'fucking': 86,
#  'An': 87,
#  'continue': 88,
#  'green': 89,
#  'milk': 90,
#  'lovely': 91,
#  'memory': 92,
#  'proven': 93,
#  'Hot': 94,
#  'INCONSIDERATE': 95,
#  'drinks': 96,
#  'reasonable': 97,
#  "'re": 98,
#  'Omelets': 99,
#  'ambiance': 100,
#  'relocated': 101,
#  'craving': 102,
#  'hands-down': 103,
#  'ourselves': 104,
#  'joke': 105,
#  'Gave': 106,
#  'breakfast/lunch': 107,
#  'dressed': 108,
#  'appetizer': 109,
#  'pecan': 110,
#  'top': 111,
#  'Not': 112,
#  'flop': 113,
#  'latte': 114,
#  'So': 115,
#  'platter': 116,
#  'spring': 117,
#  'warnings': 118,
#  'services': 119,
#  'tots': 120,
#  'closed': 121,
#  'space': 122,
#  'felt': 123,
#  'grilled': 124,
#  'flavorful': 125,
#  'bring': 126,
#  'UNREAL': 127,
#  'eggs': 128,
#  'Really': 129,
#  'cramming': 130,
#  'times': 131,
#  "'m": 132,
#  'regular': 133,
#  'RUDE': 134,
#  'tastings': 135,
#  'beers': 136,
#  'Hands': 137,
#  'Lobster': 138,
#  'somewhat': 139,
#  'owned': 140,
#  '*': 141,
#  'extensive': 142,
#  'inside': 143,
#  'needed': 144,
#  'Area': 145,
#  'simple': 146,
#  'fat': 147,
#  'tartare': 148,
#  'enjoyed': 149,
#  'Gourmet': 150,
#  'stop': 151,
#  'NASTY': 152,
#  'put': 153,
#  'poop': 154,
#  'events': 155,
#  'The': 156,
#  'Kabuki': 157,
#  'tell': 158,
#  'Our': 159,
#  'lot': 160,
#  'roasted': 161,
#  'vinegrette': 162,
#  'been-stepped-in-and-tracked-everywhere': 163,
#  'let': 164,
#  'known': 165,
#  'nasty': 166,
#  'idea': 167,
#  'ALL': 168,
#  'Baseball': 169,
#  'Four': 170,
#  'accident': 171,
#  'waitress': 172,
#  'experiencing': 173,
#  'between': 174,
#  'positive': 175,
#  'awesome': 176,
#  'started': 177,
#  'asking': 178,
#  'Must': 179,
#  '-My': 180,
#  'realized': 181,
#  'whatsoever': 182,
#  'Smashburger': 183,
#  'Grill': 184,
#  'why': 185,
#  'check': 186,
#  'pretty': 187,
#  'instantly': 188,
#  'dessert': 189,
#  'shopping': 190,
#  'calamari': 191,
#  'bucks': 192,
#  'fails': 193,
#  'inch': 194,
#  'velvet': 195,
#  'melt': 196,
#  'rest': 197,
#  'fairly': 198,
#  'NOW': 199,
#  'nachos': 200,
#  'Heart': 201,
#  'gem': 202,
#  'massive': 203,
#  'CONCLUSION': 204,
#  'melted': 205,
#  'stupid': 206,
#  'finally': 207,
#  'sushi': 208,
#  'opened': 209,
#  'did': 210,
#  'bits': 211,
#  'Only': 212,
#  'treated': 213,
#  'To': 214,
#  'effort': 215,
#  'I': 216,
#  'thumbs': 217,
#  'bathrooms': 218,
#  'Hard': 219,
#  'despicable': 220,
#  'day': 221,
#  'atmosphere.1': 222,
#  'running': 223,
#  'cheeseburger': 224,
#  'playing': 225,
#  'flavorless': 226,
#  'bathroom': 227,
#  'elegantly': 228,
#  'little': 229,
#  'ripped': 230,
#  'husband': 231,
#  'GO': 232,
#  'HAVE': 233,
#  'deserves': 234,
#  'Best': 235,
#  'hereas': 236,
#  'TOLD': 237,
#  'cart': 238,
#  'meatloaf': 239,
#  'lunch': 240,
#  'Level': 241,
#  'definately': 242,
#  'biggest': 243,
#  'by': 244,
#  'Today': 245,
#  'Big': 246,
#  'expensive': 247,
#  'read': 248,
#  'pats': 249,
#  'dirt': 250,
#  'driving': 251,
#  'and': 252,
#  'smeared': 253,
#  'chocolate': 254,
#  'decorated': 255,
#  'leftover': 256,
#  'loudly': 257,
#  'consider': 258,
#  'Good': 259,
#  'probably': 260,
#  'minutes': 261,
#  'SHOULD': 262,
#  'bad': 263,
#  'Rice': 264,
#  'delicious': 265,
#  'menu': 266,
#  'Camelback': 267,
#  'moist': 268,
#  "ya'all": 269,
#  'hilarious': 270,
#  'Mediocre': 271,
#  'croutons': 272,
#  'lil': 273,
#  'Awful': 274,
#  'cuisine': 275,
#  'three': 276,
#  'refreshing': 277,
#  'fresh': 278,
#  'boxes': 279,
#  'employees': 280,
#  'made': 281,
#  'upgrading': 282,
#  'tenders': 283,
#  'salmon': 284,
#  'terrific': 285,
#  'Risotto': 286,
#  'drinking': 287,
#  'Def': 288,
#  'consistent': 289,
#  'trimmed': 290,
#  'impressive': 291,
#  'Ironman': 292,
#  'dispenser': 293,
#  'Magic': 294,
#  'says': 295,
#  'rancheros': 296,
#  'tried': 297,
#  'beauty': 298,
#  'legit': 299,
#  'signs': 300,
#  'mostly': 301,
#  'anytime': 302,
#  'burned': 303,
#  'third': 304,
#  'donut': 305,
#  'ridiculous': 306,
#  'shocked': 307,
#  'as': 308,
#  'grill': 309,
#  'hurry': 310,
#  'atmosphere': 311,
#  '......': 312,
#  'killer': 313,
#  'forth': 314,
#  'she': 315,
#  'Things': 316,
#  'disgusted': 317,
#  'having': 318,
#  'working/eating': 319,
#  'unique': 320,
#  'Aria': 321,
#  'dude': 322,
#  'blows': 323,
#  'Furthermore': 324,
#  'cranberry': 325,
#  'Yeah': 326,
#  'portions': 327,
#  'Talk': 328,
#  'cute': 329,
#  'cashew': 330,
#  'insulted': 331,
#  'grab': 332,
#  'watched': 333,
#  'Total': 334,
#  '..': 335,
#  'coziness': 336,
#  "n't": 337,
#  'Update': 338,
#  'FREEZING': 339,
#  'buffet': 340,
#  'personable': 341,
#  'water': 342,
#  'due': 343,
#  'worst': 344,
#  'requested': 345,
#  'perfectly': 346,
#  'dirty': 347,
#  'orders': 348,
#  'refrained': 349,
#  'priced': 350,
#  'clean': 351,
#  'hair': 352,
#  'Reasonably': 353,
#  'callings': 354,
#  'letting': 355,
#  'greatest': 356,
#  'trippy': 357,
#  'needs': 358,
#  'AND': 359,
#  'shower': 360,
#  'boba': 361,
#  'Seriously': 362,
#  'Salad': 363,
#  'week': 364,
#  '17': 365,
#  'hankering': 366,
#  'guy': 367,
#  'IN': 368,
#  'crust': 369,
#  'HOUR': 370,
#  'yay': 371,
#  'eat': 372,
#  'Hiro': 373,
#  'section': 374,
#  'Lemon': 375,
#  'plain': 376,
#  '7.85': 377,
#  'tragedy': 378,
#  'station': 379,
#  'tap': 380,
#  'hottest': 381,
#  'Scottsdale': 382,
#  'enjoyable': 383,
#  'definitely': 384,
#  'raspberry': 385,
#  'flavor': 386,
#  'Mom': 387,
#  'pricey': 388,
#  'brick': 389,
#  'biscuits': 390,
#  'believe': 391,
#  'tribute': 392,
#  'salads': 393,
#  'mouth': 394,
#  'plantains': 395,
#  'get': 396,
#  'Gordon': 397,
#  'wedges': 398,
#  'bottom': 399,
#  'order': 400,
#  'pizzas': 401,
#  'shrimp': 402,
#  'without': 403,
#  '1.5lb': 404,
#  'perfection': 405,
#  'bank': 406,
#  'lack': 407,
#  'thirty': 408,
#  'watch': 409,
#  'item': 410,
#  'blandest': 411,
#  'suggestions': 412,
#  'monster': 413,
#  'palate': 414,
#  'Loved': 415,
#  'Christmas': 416,
#  'cocktail': 417,
#  'carbs': 418,
#  'table': 419,
#  'bloddy': 420,
#  'Check': 421,
#  'Have': 422,
#  'sitting': 423,
#  'but': 424,
#  'glance': 425,
#  'movies': 426,
#  'life': 427,
#  'vegetables': 428,
#  'My': 429,
#  'such': 430,
#  'toasted': 431,
#  'including': 432,
#  'outdoor': 433,
#  'ways': 434,
#  'poisoning': 435,
#  'things': 436,
#  'Could': 437,
#  'belly': 438,
#  'patio': 439,
#  'Tonight': 440,
#  'Francisco': 441,
#  'Will': 442,
#  'Bunch': 443,
#  'tapas': 444,
#  'dried': 445,
#  '70+': 446,
#  'witnessed': 447,
#  '3': 448,
#  'Caballero': 449,
#  'deep': 450,
#  'hella': 451,
#  '30s': 452,
#  'expect': 453,
#  'to-go': 454,
#  'Back': 455,
#  'ignored': 456,
#  'Seat': 457,
#  'lawyers': 458,
#  'bagels': 459,
#  'solid': 460,
#  'dirty-': 461,
#  'dusted': 462,
#  'TV': 463,
#  'petrified': 464,
#  'piano': 465,
#  'middle': 466,
#  'blame': 467,
#  'Shrimp-': 468,
#  'DELICIOUS': 469,
#  'madhouse': 470,
#  'soup': 471,
#  'WILL': 472,
#  '8': 473,
#  'cooking': 474,
#  'club': 475,
#  'ahead': 476,
#  'Third': 477,
#  'Large': 478,
#  'heart': 479,
#  'before': 480,
#  'presentation': 481,
#  'OVERPRICED': 482,
#  'from': 483,
#  'promise': 484,
#  'ratio': 485,
#  'some': 486,
#  'mac': 487,
#  'sit-down': 488,
#  'Place': 489,
#  'rapidly': 490,
#  'TIME': 491,
#  'hours': 492,
#  'tip': 493,
#  'Chipotle': 494,
#  'thought': 495,
#  'Dessert': 496,
#  'must': 497,
#  'godfathers': 498,
#  'mortified': 499,
#  'Ganoush': 500,
#  'charcoal': 501,
#  'deal': 502,
#  'Cant': 503,
#  'down': 504,
#  'leather': 505,
#  'BACK': 506,
#  'classics': 507,
#  'sauce': 508,
#  'course': 509,
#  'sweet': 510,
#  'it': 511,
#  'stuff': 512,
#  'downtown': 513,
#  'undercooked': 514,
#  'vegetarian': 515,
#  'margaritas': 516,
#  ':': 517,
#  'concern': 518,
#  'Pho': 519,
#  'delightful': 520,
#  'even': 521,
#  'luck': 522,
#  'greedy': 523,
#  'deliciously': 524,
#  'ok': 525,
#  'judge': 526,
#  'assure': 527,
#  'onion': 528,
#  'Go': 529,
#  'Mediterranean': 530,
#  'saganaki': 531,
#  'fruit': 532,
#  'usual': 533,
#  'Nice': 534,
#  'fear': 535,
#  'mom': 536,
#  'Company': 537,
#  'attention': 538,
#  'feel': 539,
#  'Nobu': 540,
#  'turkey': 541,
#  'sure': 542,
#  'unfortunately': 543,
#  'contained': 544,
#  'boring': 545,
#  'Avoid': 546,
#  'Thai': 547,
#  'rich': 548,
#  'Very': 549,
#  'Tigerlilly': 550,
#  'tops': 551,
#  'attitudes': 552,
#  'wound': 553,
#  'thanks': 554,
#  'NONE': 555,
#  'first': 556,
#  'bread': 557,
#  'Insults': 558,
#  'sunglasses': 559,
#  'Bachi': 560,
#  'poorly': 561,
#  'barely': 562,
#  'Con': 563,
#  'Jeff': 564,
#  'rare': 565,
#  'hit': 566,
#  'daughter': 567,
#  'Damn': 568,
#  'apple': 569,
#  'Are': 570,
#  'wish': 571,
#  'reservation': 572,
#  'drawing': 573,
#  'family': 574,
#  'May': 575,
#  'empty': 576,
#  'zero': 577,
#  'far': 578,
#  'Waited': 579,
#  'marrow': 580,
#  'First': 581,
#  'favorite': 582,
#  'patron': 583,
#  'Awesome': 584,
#  'final': 585,
#  'quite': 586,
#  'sense': 587,
#  'APPETIZERS': 588,
#  'Magazine': 589,
#  'heat': 590,
#  'public': 591,
#  'staff': 592,
#  'flat': 593,
#  'Sour': 594,
#  'anyone': 595,
#  'EXPERIENCE': 596,
#  'over-priced': 597,
#  'fan': 598,
#  'showed': 599,
#  'leaves': 600,
#  'summarize': 601,
#  'big': 602,
#  'Café': 603,
#  'wanted': 604,
#  'five': 605,
#  'caterpillar': 606,
#  'attentive': 607,
#  'veal': 608,
#  'mmmm': 609,
#  'expanded': 610,
#  'REAL': 611,
#  'under': 612,
#  'fabulous': 613,
#  'warmer': 614,
#  'bill': 615,
#  'store': 616,
#  'decision': 617,
#  'almost': 618,
#  'Would': 619,
#  'plastic': 620,
#  'ravoli': 621,
#  'garlic': 622,
#  'absolutley': 623,
#  'book': 624,
#  'pancakes': 625,
#  'Wife': 626,
#  'downright': 627,
#  'Phenomenal': 628,
#  'All': 629,
#  'wings': 630,
#  'prices': 631,
#  'ingredients': 632,
#  ',': 633,
#  'blue': 634,
#  'whole': 635,
#  'greasy': 636,
#  'Chicken': 637,
#  'reminded': 638,
#  'chains': 639,
#  'circumstances': 640,
#  'longer': 641,
#  'chicken': 642,
#  'fun': 643,
#  'location': 644,
#  'milkshake': 645,
#  'staying': 646,
#  'awful': 647,
#  'Sadly': 648,
#  'untoasted': 649,
#  'soundtrack': 650,
#  'although': 651,
#  'chickens': 652,
#  'ago': 653,
#  'bought': 654,
#  'great': 655,
#  'peanut': 656,
#  'occasions': 657,
#  'anymore': 658,
#  'Join': 659,
#  'next': 660,
#  'Horrible': 661,
#  'last': 662,
#  'non-fancy': 663,
#  "'ll": 664,
#  'handed': 665,
#  'southwest': 666,
#  'genuinely': 667,
#  'Veggitarian': 668,
#  'waiting': 669,
#  'Stopped': 670,
#  'shirt': 671,
#  'money': 672,
#  'mushrooms': 673,
#  'making': 674,
#  'wave': 675,
#  'forever': 676,
#  'help': 677,
#  'busy': 678,
#  'businesses': 679,
#  'similar': 680,
#  'underwhelming': 681,
#  'whether': 682,
#  'blown': 683,
#  'two': 684,
#  'mean': 685,
#  'Del': 686,
#  'spends': 687,
#  'ate': 688,
#  'tiramisu': 689,
#  'Pretty': 690,
#  '2': 691,
#  '10': 692,
#  'know': 693,
#  'decent': 694,
#  'teamwork': 695,
#  'dead': 696,
#  'pub': 697,
#  'OK': 698,
#  'STALE': 699,
#  'her': 700,
#  'degree': 701,
#  'excuse': 702,
#  'not': 703,
#  'supposed': 704,
#  'told': 705,
#  'forty': 706,
#  'nut': 707,
#  'while': 708,
#  'disrespected': 709,
#  'bar': 710,
#  'thru': 711,
#  'ala': 712,
#  'Maine': 713,
#  'their': 714,
#  'Attack': 715,
#  'being': 716,
#  'new': 717,
#  'cheesecurds': 718,
#  'Strip': 719,
#  'cake': 720,
#  'reviews': 721,
#  'colder': 722,
#  'solidify': 723,
#  'soon': 724,
#  'apart': 725,
#  'reason': 726,
#  'actual': 727,
#  'smelled': 728,
#  'dine': 729,
#  'Worse': 730,
#  'Salads': 731,
#  'cant': 732,
#  'mains': 733,
#  'bit': 734,
#  'party': 735,
#  'Outstanding': 736,
#  'returned': 737,
#  'takeout': 738,
#  'bartender': 739,
#  'break': 740,
#  'favor': 741,
#  'Excalibur': 742,
#  'vinaigrette': 743,
#  'rubber': 744,
#  'Delight': 745,
#  'chef': 746,
#  'Waitress': 747,
#  'MANAGEMENT': 748,
#  'Main': 749,
#  'overpriced': 750,
#  'summer': 751,
#  'really': 752,
#  'dish': 753,
#  'correct': 754,
#  'modern': 755,
#  'REALLY': 756,
#  'burger': 757,
#  'almonds': 758,
#  'angry': 759,
#  'none': 760,
#  'toro': 761,
#  'use': 762,
#  '45': 763,
#  'an': 764,
#  'helpful': 765,
#  'lived': 766,
#  'any': 767,
#  'world': 768,
#  'tomato': 769,
#  'itself': 770,
#  'lady': 771,
#  'unless': 772,
#  'served': 773,
#  'After': 774,
#  'banana': 775,
#  'exceptional': 776,
#  'tasteless': 777,
#  'crowd': 778,
#  'FLY': 779,
#  'twice': 780,
#  'tailored': 781,
#  '....': 782,
#  'town': 783,
#  'free': 784,
#  'ethic': 785,
#  'go': 786,
#  'Seafood': 787,
#  'rate': 788,
#  'struck': 789,
#  'name': 790,
#  'sandwiches': 791,
#  'that': 792,
#  'owners': 793,
#  'rather': 794,
#  'amount': 795,
#  'have': 796,
#  'remember': 797,
#  'nigiri': 798,
#  'discount': 799,
#  'Lastly': 800,
#  'every': 801,
#  'incredible': 802,
#  'generic': 803,
#  'pancake': 804,
#  'gloves.Everything': 805,
#  '/hand': 806,
#  'spicy': 807,
#  'dropped': 808,
#  'pastry': 809,
#  'stayed': 810,
#  'condiment': 811,
#  'Lordy': 812,
#  'now': 813,
#  'hits': 814,
#  'night': 815,
#  'WASTE': 816,
#  'completely': 817,
#  'else': 818,
#  'gotten': 819,
#  'Mushroom': 820,
#  'hello': 821,
#  'charming': 822,
#  'peas': 823,
#  'redeeming': 824,
#  'buffets': 825,
#  'college': 826,
#  'regularly': 827,
#  'disappointing': 828,
#  'loyal': 829,
#  'eaten': 830,
#  'driest': 831,
#  'creamy': 832,
#  'prepare': 833,
#  'work': 834,
#  'Cotta': 835,
#  'char': 836,
#  'Left': 837,
#  'options': 838,
#  'strip': 839,
#  'review': 840,
#  'given': 841,
#  'professional': 842,
#  'nothing': 843,
#  'worst/annoying': 844,
#  'fiancé': 845,
#  'For': 846,
#  'Maria': 847,
#  'From': 848,
#  'highly': 849,
#  'held': 850,
#  'hummus': 851,
#  'spots': 852,
#  'sucker': 853,
#  'management': 854,
#  'across': 855,
#  'rib': 856,
#  'seasonal': 857,
#  'filling': 858,
#  'spices': 859,
#  'quickly': 860,
#  'waitresses': 861,
#  'spot': 862,
#  'opposed': 863,
#  'cash': 864,
#  'shawarrrrrrma': 865,
#  'Thus': 866,
#  'bus': 867,
#  'letdown': 868,
#  'round': 869,
#  'pho': 870,
#  'saying': 871,
#  'naan': 872,
#  'giant': 873,
#  'unexperienced': 874,
#  'poured': 875,
#  'star': 876,
#  'bye': 877,
#  'couple': 878,
#  'covers': 879,
#  'appealing': 880,
#  'meat': 881,
#  'etc': 882,
#  'dime': 883,
#  'everyone': 884,
#  'Owner': 885,
#  'Maybe': 886,
#  'Caesar': 887,
#  'Terrible': 888,
#  'of': 889,
#  'friends': 890,
#  'coconut': 891,
#  'stuffed': 892,
#  'metro': 893,
#  'soooo': 894,
#  'Friend': 895,
#  'hardly': 896,
#  'a': 897,
#  'happier': 898,
#  '2007': 899,
#  'those': 900,
#  'most': 901,
#  'fella': 902,
#  'drag': 903,
#  'up': 904,
#  'double': 905,
#  'highlights': 906,
#  'wash': 907,
#  'atrocious': 908,
#  'delivery': 909,
#  'done': 910,
#  'fair': 911,
#  'might': 912,
#  'ball': 913,
#  'sliced': 914,
#  '15': 915,
#  'wonderful': 916,
#  'serve': 917,
#  'there': 918,
#  'promptly': 919,
#  'rave': 920,
#  'disbelief': 921,
#  'Never': 922,
#  'sad': 923,
#  'AZ': 924,
#  'workers': 925,
#  'less': 926,
#  'greeted': 927,
#  'crisp': 928,
#  'industry': 929,
#  'drunk': 930,
#  'comfortable': 931,
#  '1/2': 932,
#  'color': 933,
#  'neat': 934,
#  'nearly': 935,
#  '23': 936,
#  'Pineapple': 937,
#  'car': 938,
#  'over-hip': 939,
#  'would': 940,
#  'holiday': 941,
#  'jewel': 942,
#  'unprofessional': 943,
#  'Otto': 944,
#  'fry': 945,
#  'Sat': 946,
#  'foods': 947,
#  'yet': 948,
#  'used': 949,
#  'uninspired': 950,
#  'you': 951,
#  'blow': 952,
#  'possible': 953,
#  'rolls': 954,
#  'restaurant': 955,
#  'reheated': 956,
#  'hot': 957,
#  'gratitude': 958,
#  'Do': 959,
#  'certainly': 960,
#  'recommend': 961,
#  'Bar': 962,
#  'andddd': 963,
#  'raving': 964,
#  'when': 965,
#  'slaw': 966,
#  'binge': 967,
#  'sat': 968,
#  'average': 969,
#  'Overall': 970,
#  'him': 971,
#  'poor': 972,
#  'for': 973,
#  'pink': 974,
#  'rinse': 975,
#  'i': 976,
#  'pan': 977,
#  'Every': 978,
#  'NYC': 979,
#  'dealing': 980,
#  'crawfish': 981,
#  'in': 982,
#  'Blah': 983,
#  'A': 984,
#  'stay': 985,
#  'disapppointment': 986,
#  'MGM': 987,
#  'tea': 988,
#  'limited': 989,
#  'spinach': 990,
#  'handling': 991,
#  'Shop': 992,
#  '20': 993,
#  'Nargile': 994,
#  'accountant': 995,
#  'anticipated': 996,
#  'vain': 997,
#  'desired': 998,
#  'unwelcome': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: '.',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  19: '.',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  23: 'the',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  32: 'and',
#  33: 'loved',
#  34: 'it',
#  35: '.',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  39: 'the',
#  40: 'menu',
#  41: 'was',
#  42: 'great',
#  43: 'and',
#  44: 'so',
#  45: 'were',
#  46: 'the',
#  47: 'prices',
#  48: '.',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  54: 'and',
#  55: 'I',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  60: '.',
#  61: 'Honeslty',
#  62: 'it',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
#  68: '.',
#  69: ')',
#  70: 'The',
#  71: 'potatoes',
#  72: 'were',
#  73: 'like',
#  74: 'rubber',
#  75: 'and',
#  76: 'you',
#  77: 'could',
#  78: 'tell',
#  79: 'they',
#  80: 'had',
#  81: 'been',
#  82: 'made',
#  83: 'up',
#  84: 'ahead',
#  85: 'of',
#  86: 'time',
#  87: 'being',
#  88: 'kept',
#  89: 'under',
#  90: 'a',
#  91: 'warmer',
#  92: '.',
#  93: 'The',
#  94: 'fries',
#  95: 'were',
#  96: 'great',
#  97: 'too',
#  98: '.',
#  99: 'A',
#  100: 'great',
#  101: 'touch',
#  102: '.',
#  103: 'Service',
#  104: 'was',
#  105: 'very',
#  106: 'prompt',
#  107: '.',
#  108: 'Would',
#  109: 'not',
#  110: 'go',
#  111: 'back',
#  112: '.',
#  113: 'The',
#  114: 'cashier',
#  115: 'had',
#  116: 'no',
#  117: 'care',
#  118: 'what',
#  119: 'so',
#  120: 'ever',
#  121: 'on',
#  122: 'what',
#  123: 'I',
#  124: 'had',
#  125: 'to',
#  126: 'say',
#  127: 'it',
#  128: 'still',
#  129: 'ended',
#  130: 'up',
#  131: 'being',
#  132: 'wayyy',
#  133: 'overpriced',
#  134: '.',
#  135: 'I',
#  136: 'tried',
#  137: 'the',
#  138: 'Cape',
#  139: 'Cod',
#  140: 'ravoli',
#  141: ',',
#  142: 'chicken',
#  143: ',',
#  144: 'with',
#  145: 'cranberry',
#  146: '...',
#  147: 'mmmm',
#  148: '!',
#  149: 'I',
#  150: 'was',
#  151: 'disgusted',
#  152: 'because',
#  153: 'I',
#  154: 'was',
#  155: 'pretty',
#  156: 'sure',
#  157: 'that',
#  158: 'was',
#  159: 'human',
#  160: 'hair',
#  161: '.',
#  162: 'I',
#  163: 'was',
#  164: 'shocked',
#  165: 'because',
#  166: 'no',
#  167: 'signs',
#  168: 'indicate',
#  169: 'cash',
#  170: 'only',
#  171: '.',
#  172: 'Highly',
#  173: 'recommended',
#  174: '.',
#  175: 'Waitress',
#  176: 'was',
#  177: 'a',
#  178: 'little',
#  179: 'slow',
#  180: 'in',
#  181: 'service',
#  182: '.',
#  183: 'This',
#  184: 'place',
#  185: 'is',
#  186: 'not',
#  187: 'worth',
#  188: 'your',
#  189: 'time',
#  190: ',',
#  191: 'let',
#  192: 'alone',
#  193: 'Vegas',
#  194: '.',
#  195: 'did',
#  196: 'not',
#  197: 'like',
#  198: 'at',
#  199: 'all',
#  200: '.',
#  201: 'The',
#  202: 'Burrittos',
#  203: 'Blah',
#  204: '!',
#  205: 'The',
#  206: 'food',
#  207: ',',
#  208: 'amazing',
#  209: '.',
#  210: 'Service',
#  211: 'is',
#  212: 'also',
#  213: 'cute',
#  214: '.',
#  215: 'I',
#  216: 'could',
#  217: 'care',
#  218: 'less',
#  219: '...',
#  220: 'The',
#  221: 'interior',
#  222: 'is',
#  223: 'just',
#  224: 'beautiful',
#  225: '.',
#  226: 'So',
#  227: 'they',
#  228: 'performed',
#  229: '.',
#  230: 'That',
#  231: "'s",
#  232: 'right',
#  233: '...',
#  234: '.the',
#  235: 'red',
#  236: 'velvet',
#  237: 'cake',
#  238: '...',
#  239: '..ohhh',
#  240: 'this',
#  241: 'stuff',
#  242: 'is',
#  243: 'so',
#  244: 'good',
#  245: '.',
#  246: '-',
#  247: 'They',
#  248: 'never',
#  249: 'brought',
#  250: 'a',
#  251: 'salad',
#  252: 'we',
#  253: 'asked',
#  254: 'for',
#  255: '.',
#  256: 'This',
#  257: 'hole',
#  258: 'in',
#  259: 'the',
#  260: 'wall',
#  261: 'has',
#  262: 'great',
#  263: 'Mexican',
#  264: 'street',
#  265: 'tacos',
#  266: ',',
#  267: 'and',
#  268: 'friendly',
#  269: 'staff',
#  270: '.',
#  271: 'Took',
#  272: 'an',
#  273: 'hour',
#  274: 'to',
#  275: 'get',
#  276: 'our',
#  277: 'food',
#  278: 'only',
#  279: '4',
#  280: 'tables',
#  281: 'in',
#  282: 'restaurant',
#  283: 'my',
#  284: 'food',
#  285: 'was',
#  286: 'Luke',
#  287: 'warm',
#  288: ',',
#  289: 'Our',
#  290: 'sever',
#  291: 'was',
#  292: 'running',
#  293: 'around',
#  294: 'like',
#  295: 'he',
#  296: 'was',
#  297: 'totally',
#  298: 'overwhelmed',
#  299: '.',
#  300: 'The',
#  301: 'worst',
#  302: 'was',
#  303: 'the',
#  304: 'salmon',
#  305: 'sashimi',
#  306: '.',
#  307: 'Also',
#  308: 'there',
#  309: 'are',
#  310: 'combos',
#  311: 'like',
#  312: 'a',
#  313: 'burger',
#  314: ',',
#  315: 'fries',
#  316: ',',
#  317: 'and',
#  318: 'beer',
#  319: 'for',
#  320: '23',
#  321: 'which',
#  322: 'is',
#  323: 'a',
#  324: 'decent',
#  325: 'deal',
#  326: '.',
#  327: 'This',
#  328: 'was',
#  329: 'like',
#  330: 'the',
#  331: 'final',
#  332: 'blow',
#  333: '!',
#  334: 'I',
#  335: 'found',
#  336: 'this',
#  337: 'place',
#  338: 'by',
#  339: 'accident',
#  340: 'and',
#  341: 'I',
#  342: 'could',
#  343: 'not',
#  344: 'be',
#  345: 'happier',
#  346: '.',
#  347: 'seems',
#  348: 'like',
#  349: 'a',
#  350: 'good',
#  351: 'quick',
#  352: 'place',
#  353: 'to',
#  354: 'grab',
#  355: 'a',
#  356: 'bite',
#  357: 'of',
#  358: 'some',
#  359: 'familiar',
#  360: 'pub',
#  361: 'food',
#  362: ',',
#  363: 'but',
#  364: 'do',
#  365: 'yourself',
#  366: 'a',
#  367: 'favor',
#  368: 'and',
#  369: 'look',
#  370: 'elsewhere',
#  371: '.',
#  372: 'Overall',
#  373: ',',
#  374: 'I',
#  375: 'like',
#  376: 'this',
#  377: 'place',
#  378: 'a',
#  379: 'lot',
#  380: '.',
#  381: 'The',
#  382: 'only',
#  383: 'redeeming',
#  384: 'quality',
#  385: 'of',
#  386: 'the',
#  387: 'restaurant',
#  388: 'was',
#  389: 'that',
#  390: 'it',
#  391: 'was',
#  392: 'very',
#  393: 'inexpensive',
#  394: '.',
#  395: 'Ample',
#  396: 'portions',
#  397: 'and',
#  398: 'good',
#  399: 'prices',
#  400: '.',
#  401: 'Poor',
#  402: 'service',
#  403: ',',
#  404: 'the',
#  405: 'waiter',
#  406: 'made',
#  407: 'me',
#  408: 'feel',
#  409: 'like',
#  410: 'I',
#  411: 'was',
#  412: 'stupid',
#  413: 'every',
#  414: 'time',
#  415: 'he',
#  416: 'came',
#  417: 'to',
#  418: 'the',
#  419: 'table',
#  420: '.',
#  421: 'My',
#  422: 'first',
#  423: 'visit',
#  424: 'to',
#  425: 'Hiro',
#  426: 'was',
#  427: 'a',
#  428: 'delight',
#  429: '!',
#  430: 'Service',
#  431: 'sucks',
#  432: '.',
#  433: 'The',
#  434: 'shrimp',
#  435: 'tender',
#  436: 'and',
#  437: 'moist',
#  438: '.',
#  439: 'There',
#  440: 'is',
#  441: 'not',
#  442: 'a',
#  443: 'deal',
#  444: 'good',
#  445: 'enough',
#  446: 'that',
#  447: 'would',
#  448: 'drag',
#  449: 'me',
#  450: 'into',
#  451: 'that',
#  452: 'establishment',
#  453: 'again',
#  454: '.',
#  455: 'Hard',
#  456: 'to',
#  457: 'judge',
#  458: 'whether',
#  459: 'these',
#  460: 'sides',
#  461: 'were',
#  462: 'good',
#  463: 'because',
#  464: 'we',
#  465: 'were',
#  466: 'grossed',
#  467: 'out',
#  468: 'by',
#  469: 'the',
#  470: 'melted',
#  471: 'styrofoam',
#  472: 'and',
#  473: 'did',
#  474: "n't",
#  475: 'want',
#  476: 'to',
#  477: 'eat',
#  478: 'it',
#  479: 'for',
#  480: 'fear',
#  481: 'of',
#  482: 'getting',
#  483: 'sick',
#  484: '.',
#  485: 'On',
#  486: 'a',
#  487: 'positive',
#  488: 'note',
#  489: ',',
#  490: 'our',
#  491: 'server',
#  492: 'was',
#  493: 'very',
#  494: 'attentive',
#  495: 'and',
#  496: 'provided',
#  497: 'great',
#  498: 'service',
#  499: '.',
#  500: 'Frozen',
#  501: 'pucks',
#  502: 'of',
#  503: 'disgust',
#  504: ',',
#  505: 'with',
#  506: 'some',
#  507: 'of',
#  508: 'the',
#  509: 'worst',
#  510: 'people',
#  511: 'behind',
#  512: 'the',
#  513: 'register',
#  514: '.',
#  515: 'The',
#  516: 'only',
#  517: 'thing',
#  518: 'I',
#  519: 'did',
#  520: 'like',
#  521: 'was',
#  522: 'the',
#  523: 'prime',
#  524: 'rib',
#  525: 'and',
#  526: 'dessert',
#  527: 'section',
#  528: '.',
#  529: 'It',
#  530: "'s",
#  531: 'too',
#  532: 'bad',
#  533: 'the',
#  534: 'food',
#  535: 'is',
#  536: 'so',
#  537: 'damn',
#  538: 'generic',
#  539: '.',
#  540: 'The',
#  541: 'burger',
#  542: 'is',
#  543: 'good',
#  544: 'beef',
#  545: ',',
#  546: 'cooked',
#  547: 'just',
#  548: 'right',
#  549: '.',
#  550: 'If',
#  551: 'you',
#  552: 'want',
#  553: 'a',
#  554: 'sandwich',
#  555: 'just',
#  556: 'go',
#  557: 'to',
#  558: 'any',
#  559: 'Firehouse',
#  560: '!',
#  561: '!',
#  562: '!',
#  563: '!',
#  564: '!',
#  565: 'My',
#  566: 'side',
#  567: 'Greek',
#  568: 'salad',
#  569: 'with',
#  570: 'the',
#  571: 'Greek',
#  572: 'dressing',
#  573: 'was',
#  574: 'so',
#  575: 'tasty',
#  576: ',',
#  577: 'and',
#  578: 'the',
#  579: 'pita',
#  580: 'and',
#  581: 'hummus',
#  582: 'was',
#  583: 'very',
#  584: 'refreshing',
#  585: '.',
#  586: 'We',
#  587: 'ordered',
#  588: 'the',
#  589: 'duck',
#  590: 'rare',
#  591: 'and',
#  592: 'it',
#  593: 'was',
#  594: 'pink',
#  595: 'and',
#  596: 'tender',
#  597: 'on',
#  598: 'the',
#  599: 'inside',
#  600: 'with',
#  601: 'a',
#  602: 'nice',
#  603: 'char',
#  604: 'on',
#  605: 'the',
#  606: 'outside',
#  607: '.',
#  608: 'He',
#  609: 'came',
#  610: 'running',
#  611: 'after',
#  612: 'us',
#  613: 'when',
#  614: 'he',
#  615: 'realized',
#  616: 'my',
#  617: 'husband',
#  618: 'had',
#  619: 'left',
#  620: 'his',
#  621: 'sunglasses',
#  622: 'on',
#  623: 'the',
#  624: 'table',
#  625: '.',
#  626: 'Their',
#  627: 'chow',
#  628: 'mein',
#  629: 'is',
#  630: 'so',
#  631: 'good',
#  632: '!',
#  633: 'They',
#  634: 'have',
#  635: 'horrible',
#  636: 'attitudes',
#  637: 'towards',
#  638: 'customers',
#  639: ',',
#  640: 'and',
#  641: 'talk',
#  642: 'down',
#  643: 'to',
#  644: 'each',
#  645: 'one',
#  646: 'when',
#  647: 'customers',
#  648: 'do',
#  649: "n't",
#  650: 'enjoy',
#  651: 'their',
#  652: 'food',
#  653: '.',
#  654: 'The',
#  655: 'portion',
#  656: 'was',
#  657: 'huge',
#  658: '!',
#  659: 'Loved',
#  660: 'it',
#  661: '...',
#  662: 'friendly',
#  663: 'servers',
#  664: ',',
#  665: 'great',
#  666: 'food',
#  667: ',',
#  668: 'wonderful',
#  669: 'and',
#  670: 'imaginative',
#  671: 'menu',
#  672: '.',
#  673: 'The',
#  674: 'Heart',
#  675: 'Attack',
#  676: 'Grill',
#  677: 'in',
#  678: 'downtown',
#  679: 'Vegas',
#  680: 'is',
#  681: 'an',
#  682: 'absolutely',
#  683: 'flat-lined',
#  684: 'excuse',
#  685: 'for',
#  686: 'a',
#  687: 'restaurant',
#  688: '.',
#  689: 'Not',
#  690: 'much',
#  691: 'seafood',
#  692: 'and',
#  693: 'like',
#  694: '5',
#  695: 'strings',
#  696: 'of',
#  697: 'pasta',
#  698: 'at',
#  699: 'the',
#  700: 'bottom',
#  701: '.',
#  702: 'The',
#  703: 'salad',
#  704: 'had',
#  705: 'just',
#  706: 'the',
#  707: 'right',
#  708: 'amount',
#  709: 'of',
#  710: 'sauce',
#  711: 'to',
#  712: 'not',
#  713: 'over',
#  714: 'power',
#  715: 'the',
#  716: 'scallop',
#  717: ',',
#  718: 'which',
#  719: 'was',
#  720: 'perfectly',
#  721: 'cooked',
#  722: '.',
#  723: 'The',
#  724: 'ripped',
#  725: 'banana',
#  726: 'was',
#  727: 'not',
#  728: 'only',
#  729: 'ripped',
#  730: ',',
#  731: 'but',
#  732: 'petrified',
#  733: 'and',
#  734: 'tasteless',
#  735: '.',
#  736: 'At',
#  737: 'least',
#  738: 'think',
#  739: 'to',
#  740: 'refill',
#  741: 'my',
#  742: 'water',
#  743: 'before',
#  744: 'I',
#  745: 'struggle',
#  746: 'to',
#  747: 'wave',
#  748: 'you',
#  749: 'over',
#  750: 'for',
#  751: '10',
#  752: 'minutes',
#  753: '.',
#  754: 'This',
#  755: 'place',
#  756: 'receives',
#  757: 'stars',
#  758: 'for',
#  759: 'their',
#  760: 'APPETIZERS',
#  761: '!',
#  762: '!',
#  763: '!',
#  764: 'The',
#  765: 'cocktails',
#  766: 'are',
#  767: 'all',
#  768: 'handmade',
#  769: 'and',
#  770: 'delicious',
#  771: '.',
#  772: 'We',
#  773: "'d",
#  774: 'definitely',
#  775: 'go',
#  776: 'back',
#  777: 'here',
#  778: 'again',
#  779: '.',
#  780: 'We',
#  781: 'are',
#  782: 'so',
#  783: 'glad',
#  784: 'we',
#  785: 'found',
#  786: 'this',
#  787: 'place',
#  788: '.',
#  789: 'Great',
#  790: 'food',
#  791: 'and',
#  792: 'service',
#  793: ',',
#  794: 'huge',
#  795: 'portions',
#  796: 'and',
#  797: 'they',
#  798: 'give',
#  799: 'a',
#  800: 'military',
#  801: 'discount',
#  802: '.',
#  803: 'Always',
#  804: 'a',
#  805: 'great',
#  806: 'time',
#  807: 'at',
#  808: 'Dos',
#  809: 'Gringos',
#  810: '!',
#  811: 'Update',
#  812: '...',
#  813: '..went',
#  814: 'back',
#  815: 'for',
#  816: 'a',
#  817: 'second',
#  818: 'time',
#  819: 'and',
#  820: 'it',
#  821: 'was',
#  822: 'still',
#  823: 'just',
#  824: 'as',
#  825: 'amazing',
#  826: 'We',
#  827: 'got',
#  828: 'the',
#  829: 'food',
#  830: 'and',
#  831: 'apparently',
#  832: 'they',
#  833: 'have',
#  834: 'never',
#  835: 'heard',
#  836: 'of',
#  837: 'salt',
#  838: 'and',
#  839: 'the',
#  840: 'batter',
#  841: 'on',
#  842: 'the',
#  843: 'fish',
#  844: 'was',
#  845: 'chewy',
#  846: '.',
#  847: 'A',
#  848: 'great',
#  849: 'way',
#  850: 'to',
#  851: 'finish',
#  852: 'a',
#  853: 'great',
#  854: '.',
#  855: 'The',
#  856: 'deal',
#  857: 'included',
#  858: '5',
#  859: 'tastings',
#  860: 'and',
#  861: '2',
#  862: 'drinks',
#  863: ',',
#  864: 'and',
#  865: 'Jeff',
#  866: 'went',
#  867: 'above',
#  868: 'and',
#  869: 'beyond',
#  870: 'what',
#  871: 'we',
#  872: 'expected',
#  873: '.',
#  874: '-',
#  875: 'Really',
#  876: ',',
#  877: 'really',
#  878: 'good',
#  879: 'rice',
#  880: ',',
#  881: 'all',
#  882: 'the',
#  883: 'time',
#  884: '.',
#  885: 'The',
#  886: 'service',
#  887: 'was',
#  888: 'meh',
#  889: '.',
#  890: 'It',
#  891: 'took',
#  892: 'over',
#  893: '30',
#  894: 'min',
#  895: 'to',
#  896: 'get',
#  897: 'their',
#  898: 'milkshake',
#  899: ',',
#  900: 'which',
#  901: 'was',
#  902: 'nothing',
#  903: 'more',
#  904: 'than',
#  905: 'chocolate',
#  906: 'milk',
#  907: '.',
#  908: 'I',
#  909: 'guess',
#  910: 'I',
#  911: 'should',
#  912: 'have',
#  913: 'known',
#  914: 'that',
#  915: 'this',
#  916: 'place',
#  917: 'would',
#  918: 'suck',
#  919: ',',
#  920: 'because',
#  921: 'it',
#  922: 'is',
#  923: 'inside',
#  924: 'of',
#  925: 'the',
#  926: 'Excalibur',
#  927: ',',
#  928: 'but',
#  929: 'I',
#  930: 'did',
#  931: "n't",
#  932: 'use',
#  933: 'my',
#  934: 'common',
#  935: 'sense',
#  936: '.',
#  937: 'The',
#  938: 'scallop',
#  939: 'dish',
#  940: 'is',
#  941: 'quite',
#  942: 'appalling',
#  943: 'for',
#  944: 'value',
#  945: 'as',
#  946: 'well',
#  947: '.',
#  948: '2',
#  949: 'times',
#  950: '-',
#  951: 'Very',
#  952: 'Bad',
#  953: 'Customer',
#  954: 'Service',
#  955: '!',
#  956: 'The',
#  957: 'sweet',
#  958: 'potato',
#  959: 'fries',
#  960: 'were',
#  961: 'very',
#  962: 'good',
#  963: 'and',
#  964: 'seasoned',
#  965: 'well',
#  966: '.',
#  967: 'Today',
#  968: 'is',
#  969: 'the',
#  970: 'second',
#  971: 'time',
#  972: 'I',
#  973: "'ve",
#  974: 'been',
#  975: 'to',
#  976: 'their',
#  977: 'lunch',
#  978: 'buffet',
#  979: 'and',
#  980: 'it',
#  981: 'was',
#  982: 'pretty',
#  983: 'good',
#  984: '.',
#  985: 'There',
#  986: 'is',
#  987: 'so',
#  988: 'much',
#  989: 'good',
#  990: 'food',
#  991: 'in',
#  992: 'Vegas',
#  993: 'that',
#  994: 'I',
#  995: 'feel',
#  996: 'cheated',
#  997: 'for',
#  998: 'wasting',
#  999: 'an',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index_dic[word]] +=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
